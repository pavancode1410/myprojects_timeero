# %%
print('hello')
# Out:
# hello

# %%
import requests

url = "https://rest.tsheets.com/api/v1/authorize"

querystring = {
  "response_type":"code",
  "client_id":"6b9f81fda8d050c501ba76f4790b41ce",
  "redirect_uri":"https://somedomain.com/callback",
  "state":"MYSTATE",
}

payload = ""
headers = {
  }

response = requests.request("GET", url, data=payload, headers=headers, params=querystring)

print(response.text)
# Out:
# Bad Request <br /> Error: redirect_uri_mismatch <br /> Description: The redirect URI provided is missing or does not match<br /><br /><b>Authentication cannot proceed until this is corrected!</b><br /><br />Please contact the application owner that sent you here to get this fixed.

# %%
import urllib.parse

base_url = "https://rest.tsheets.com/api/v1/authorize"
params = {
     "response_type": "code",
     "client_id": "6b9f81fda8d050c501ba76f4790b41ce",
     "redirect_uri": "https://get.com",  # <-- update this to match
     "state": "MYSTATE"
}

# Create the full URL to open in a browser
auth_url = f"{base_url}?{urllib.parse.urlencode(params)}"
print("Visit this URL in a browser to authorize:")
print(auth_url)
# Out:
# Visit this URL in a browser to authorize:
# https://rest.tsheets.com/api/v1/authorize?response_type=code&client_id=6b9f81fda8d050c501ba76f4790b41ce&redirect_uri=https%3A%2F%2Fget.com&state=MYSTATE

# %%
import requests

token_url = "https://oauth.platform.intuit.com/oauth2/v1/tokens/bearer"

data = {
    "grant_type": "authorization_code",
    "client_id": "6b9f81fda8d050c501ba76f4790b41ce",
    "client_secret": "28a2d6498a656be7caf250ef11af8d51",  # from your app
    "code": "6009ec9827522b38f8769fe650c3d9a99605b8da",  # replace with actual code
    "redirect_uri": "https://get.com"
}

response = requests.post(token_url, data=data)
print(response.json())
# Out:
# {'error': 'invalid_grant'}

# %%
import requests
from requests.auth import HTTPBasicAuth

token_url = "https://oauth.platform.intuit.com/oauth2/v1/tokens/bearer"

client_id = "6b9f81fda8d050c501ba76f4790b41ce"
client_secret = "28a2d6498a656be7caf250ef11af8d51"

data = {
    "grant_type": "authorization_code",
    "code": "66e92580a8847e7a7d60a3e679c058ddaae9efa1",
    "redirect_uri": "https://get.com"
}

headers = {
    "Accept": "application/json",
    "Content-Type": "application/x-www-form-urlencoded"
}

response = requests.post(
    token_url,
    data=data,
    auth=HTTPBasicAuth(client_id, client_secret),
    headers=headers
)

print(response.json())
# Out:
# {'error': 'invalid_grant'}

# %%
import requests
import json

# Replace with your actual access token from the screenshot
# IMPORTANT: In a real application, you would dynamically get this token
# from the response of your authorization code exchange, not hardcode it.
access_token = "S.7_66ff92b4db402caf5da98f19235e26e39232bbc0"

# Replace with the appropriate Intuit API endpoint you want to access
# Example: For QuickBooks Time, it might look something like:
# base_url = "https://api.intuit.com/quickbooks/v4/companies/YOUR_COMPANY_ID/reports"
# or specific to QuickBooks Online:
# base_url = "https://sandbox-quickbooks.api.intuit.com/v3/company/YOUR_REALM_ID/query?query=SELECT%20*%20FROM%20Customer"
# You'll need to consult the Intuit API documentation for the exact endpoint and parameters.
api_endpoint = "https://sandbox-quickbooks.api.intuit.com/v3/company/YOUR_REALM_ID/query?query=SELECT%20*%20FROM%20Customer" # Example placeholder

# Headers for the authenticated request
headers = {
    "Authorization": f"Bearer {access_token}",
    "Accept": "application/json",
    "Content-Type": "application/json" # Often needed for POST/PUT, good practice to include
}

try:
    # Make the GET request to the API endpoint
    response = requests.get(api_endpoint, headers=headers)

    # Check if the request was successful (status code 200)
    response.raise_for_status()

    # Print the JSON response
    print("API Response:")
    print(json.dumps(response.json(), indent=4))

except requests.exceptions.HTTPError as e:
    print(f"HTTP Error: {e}")
    print(f"Response content: {response.text}")
except requests.exceptions.RequestException as e:
    print(f"Request Error: {e}")
except json.JSONDecodeError:
    print(f"Error decoding JSON: {response.text}")
# Out:
# HTTP Error: 401 Client Error: Unauthorized for url: https://sandbox-quickbooks.api.intuit.com/v3/company/YOUR_REALM_ID/query?query=SELECT%20*%20FROM%20Customer
# Response content: {"warnings":null,"intuitObject":null,"fault":{"error":[{"message":"message=AuthenticationFailed; errorCode=003200; statusCode=401","detail":"Malformed bearer token: too short or too long","code":"3200","element":null}],"type":"AUTHENTICATION"},"report":null,"queryResponse":null,"batchItemResponse":[],"attachableResponse":[],"syncErrorResponse":null,"requestId":null,"time":1754679671127,"status":null,"cdcresponse":[]}

# %%
import requests

url = "https://rest.tsheets.com/api/v1/users"

querystring = {
  "limit":"1",
}

payload = ""
headers = {
   'Authorization': "Bearer S.7__66ff92b4db402caf5da98f19235e26e39232bbc0",
  }

response = requests.request("GET", url, data=payload, headers=headers, params=querystring)

print(response.text)
# Out:
# {
#  "results": {
#   "users": {
#    "934085": {
#     "id": 934085,
#     "first_name": "Thomas",
#     "last_name": "Jefferson",
#     "display_name": "",
#     "group_id": 0,
#     "active": true,
#     "employee_number": 0,
#     "salaried": false,
#     "exempt": false,
#     "username": "bakwarte2@gmail.com",
#     "email": "bakwarte2@gmail.com",
#     "email_verified": true,
#     "payroll_id": "",
#     "hire_date": "0000-00-00",
#     "term_date": "0000-00-00",
#     "last_modified": "2024-08-14T16:18:28+00:00",
#     "last_active": "2025-08-08T18:12:04+00:00",
#     "created": "2018-11-06T16:57:58+00:00",
#     "client_url": "jeffersonacct",
#     "company_name": "Jefferson accounting",
#     "profile_image_url": "https:\/\/www.gravatar.com\/avatar\/6b11aef7ee496e05b611170176f2e0bf",
#     "mobile_number": "",
#     "pto_balances": {
#      "6828763": 0,
#      "6828765": 0,
#      "6828767": 0,
#      "28851761": 7200,
#      "28851763": 0,
#      "28851765": 0,
# ...

# %%
import requests

url = "https://rest.tsheets.com/api/v1/users"

querystring = {
  "limit":"5",
  "usernames":"Jefferson",
}

payload = ""
headers = {
   'Authorization': "Bearer S.7__66ff92b4db402caf5da98f19235e26e39232bbc0",
  }

response = requests.request("GET", url, data=payload, headers=headers, params=querystring)

print(response.text)
# Out:
# {
#  "results": {
#   "users": {
#
#   }
#  },
#  "more": false
# }

# %%
import requests
import json

# Your access token
# Replace this with the token you get from the OAuth flow
access_token = "S.7__66ff92b4db402caf5da98f19235e26e39232bbc0"

# The base URL for the QuickBooks Time API
base_url = "https://rest.tsheets.com/api/v1/users"

# The specific user ID you want to update
user_id = "934085"

# The new hire date you want to set
new_hire_date = "2024-01-15"

# The API endpoint for updating a specific user
update_url = f"{base_url}/{user_id}"

# The data you want to send to the API.
# It's a JSON object with the fields you want to update.
update_data = {
    "hire_date": new_hire_date
}

# The headers for the request, including your access token
headers = {
    "Authorization": "Bearer S.7__66ff92b4db402caf5da98f19235e26e39232bbc0",
    "Content-Type": "application/json",
    "Accept": "application/json"
}

try:
    # Send the PUT request to the API
    print(f"Sending PUT request to: {update_url}")
    response = requests.put(update_url, data=json.dumps(update_data), headers=headers)

    # Raise an exception for bad status codes (4xx or 5xx)
    response.raise_for_status()

    # Parse and print the response from the API
    print("User updated successfully!")
    print(json.dumps(response.json(), indent=4))

except requests.exceptions.HTTPError as err:
    print(f"HTTP error occurred: {err}")
    print(f"Response content: {response.text}")
except Exception as err:
    print(f"An unexpected error occurred: {err}")
# Out:
# Sending PUT request to: https://rest.tsheets.com/api/v1/users/934085
# HTTP error occurred: 404 Client Error: Not Found for url: https://rest.tsheets.com/api/v1/users/934085
# Response content: {
#  "error": {
#   "code": 404,
#   "message": "Not Found"
#  }
# }

# %%
import requests
import json

# Your access token
# Replace this with the token you get from the OAuth flow
access_token = "S.7__66ff92b4db402caf5da98f19235e26e39232bbc0"

# The correct base URL for the QuickBooks Time API
base_url = "https://rest.tsheets.com/api/v1/users"

# The specific user ID you want to update
user_id = "934085"

# The new hire date you want to set
new_mobile_number = "6698888888"
new_employee_panel_display_name = "Thomas Edison"

# The data you want to send to the API.
# It's a JSON object with a "users" key containing the user data.
update_data = {
    "users": {
        user_id: {
            "id": user_id,
            "employee_panel_display_name": new_employee_panel_display_name
        }
    }
}

# The headers for the request, including your access token
headers = {
    "Authorization": f"Bearer {access_token}",
    "Content-Type": "application/json",
    "Accept": "application/json"
}

try:
    # Send the PUT request to the API
    print(f"Sending PUT request to: {base_url}")
    response = requests.put(base_url, data=json.dumps(update_data), headers=headers)

    # Raise an exception for bad status codes (4xx or 5xx)
    response.raise_for_status()

    # Parse and print the response from the API
    print("User updated successfully!")
    print(json.dumps(response.json(), indent=4))

except requests.exceptions.HTTPError as err:
    print(f"HTTP error occurred: {err}")
    print(f"Response content: {response.text}")
except Exception as err:
    print(f"An unexpected error occurred: {err}")
# Out:
# Sending PUT request to: https://rest.tsheets.com/api/v1/users
# HTTP error occurred: 417 Client Error: Expectation Failed for url: https://rest.tsheets.com/api/v1/users
# Response content: {
#  "error": {
#   "code": 417,
#   "message": "Expectation Failed: data field missing"
#  }
# }

# %%
import requests
import json

# Your access token
# Replace this with your actual token
access_token = "S.7__66ff92b4db402caf5da98f19235e26e39232bbc0"

# The correct base URL for the QuickBooks Time API
base_url = "https://rest.tsheets.com/api/v1/users"

# The specific user ID you want to update
user_id = "934085"

# The new first and last names you want to set
new_first_name = "Jane"
new_last_name = "Doe"

# The data MUST be structured with a "users" key
# The value is an object where the key is the user ID and the value is the fields to update
update_data = {
    "users": {
        user_id: {
            "id": int(user_id),
            "first_name": new_first_name,
            "last_name": new_last_name
        }
    }
}

# The headers for the request
headers = {
    "Authorization": f"Bearer {access_token}",
    "Content-Type": "application/json",
    "Accept": "application/json"
}

try:
    print(f"Sending PUT request to: {base_url}")
    # The data= argument must contain the JSON payload, converted to a string
    response = requests.put(base_url, data=json.dumps(update_data), headers=headers)

    # Raise an exception for bad status codes (4xx or 5xx)
    response.raise_for_status()

    # Parse and print the response from the API
    print("User updated successfully!")
    print(json.dumps(response.json(), indent=4))

except requests.exceptions.HTTPError as err:
    print(f"HTTP error occurred: {err}")
    print(f"Response content: {response.text}")
except Exception as err:
    print(f"An unexpected error occurred: {err}")
# Out:
# Sending PUT request to: https://rest.tsheets.com/api/v1/users
# HTTP error occurred: 417 Client Error: Expectation Failed for url: https://rest.tsheets.com/api/v1/users
# Response content: {
#  "error": {
#   "code": 417,
#   "message": "Expectation Failed: data field missing"
#  }
# }

# %%
import requests

# Example values
user_id = "934085"
new_first_name = "John"
new_last_name = "Doe"

url = "https://rest.tsheets.com/api/v1/users"

payload = {
    "users": {
        user_id: {
            "id": int(user_id),
            "first_name": new_first_name,
            "last_name": new_last_name
        }
    }
}

headers = {
    'Authorization': 'Bearer S.7__66ff92b4db402caf5da98f19235e26e39232bbc0',
    'Content-Type': 'application/json',
}

response = requests.put(url, json=payload, headers=headers)

print(response.status_code)
print(response.text)
# Out:
# 417
# {
#  "error": {
#   "code": 417,
#   "message": "Expectation Failed: data field missing"
#  }
# }

# %%
import requests

url = "https://rest.tsheets.com/api/v1/users"

querystring = {
  "limit":"1",
}

payload = ""
headers = {
   'Authorization': "Bearer S.7__66ff92b4db402caf5da98f19235e26e39232bbc0",
  }

response = requests.request("GET", url, data=payload, headers=headers, params=querystring)

print(response.text)
# Out:
# {
#  "results": {
#   "users": {
#    "934085": {
#     "id": 934085,
#     "first_name": "Thomas",
#     "last_name": "Jefferson",
#     "display_name": "",
#     "group_id": 0,
#     "active": true,
#     "employee_number": 0,
#     "salaried": false,
#     "exempt": false,
#     "username": "bakwarte2@gmail.com",
#     "email": "bakwarte2@gmail.com",
#     "email_verified": true,
#     "payroll_id": "",
#     "hire_date": "0000-00-00",
#     "term_date": "0000-00-00",
#     "last_modified": "2024-08-14T16:18:28+00:00",
#     "last_active": "2025-08-08T18:12:04+00:00",
#     "created": "2018-11-06T16:57:58+00:00",
#     "client_url": "jeffersonacct",
#     "company_name": "Jefferson accounting",
#     "profile_image_url": "https:\/\/www.gravatar.com\/avatar\/6b11aef7ee496e05b611170176f2e0bf",
#     "mobile_number": "",
#     "pto_balances": {
#      "6828763": 0,
#      "6828765": 0,
#      "6828767": 0,
#      "28851761": 7200,
#      "28851763": 0,
#      "28851765": 0,
# ...

# %%
import requests

# User details from GET request
user_id = "934085"
new_first_name = "Tom"  # Change you want to make

url = "https://rest.tsheets.com/api/v1/users"

payload = {
    "users": {
        user_id: {
            "id": int(user_id),
            "first_name": new_first_name
        }
    }
}

headers = {
    'Authorization': 'Bearer S.7__66ff92b4db402caf5da98f19235e26e39232bbc0',
    'Content-Type': 'application/json',
}

# Send the update request
response = requests.put(url, json=payload, headers=headers)

print(response.status_code)
print(response.text)
# Out:
# 417
# {
#  "error": {
#   "code": 417,
#   "message": "Expectation Failed: data field missing"
#  }
# }

# %%
import requests

url = "https://rest.tsheets.com/api/v1/users"

payload = {
    "users": {
        "1": {  # The key here is just a temporary reference ID for this request
            "first_name": "Alice",
            "last_name": "Johnson",
            "email": "alice.johnson@example.com",
            "username": "alice.johnson@example.com",
            "active": True
        }
    }
}

headers = {
    'Authorization': 'Bearer S.7__66ff92b4db402caf5da98f19235e26e39232bbc0',
    'Content-Type': 'application/json',
}

response = requests.post(url, json=payload, headers=headers)

print(response.status_code)
print(response.text)
# Out:
# 417
# {
#  "error": {
#   "code": 417,
#   "message": "Expectation Failed: data field missing"
#  }
# }

# %%
import requests

url = "https://rest.tsheets.com/api/v1/customfields"

payload = {
    "data": [
        {
            "name": "Vehicle Number",
            "required": True,
            "active": True,
            "applies_to": "timesheet",
            "type": "managed-list",
            "show_to_all": True,
            "short_code": "vin"
        }
    ]
}

headers = {
    'Authorization': 'Bearer S.7__66ff92b4db402caf5da98f19235e26e39232bbc0',
    'Content-Type': 'application/json',
}

response = requests.post(url, json=payload, headers=headers)

print(response.status_code)
print(response.text)
# Out:
# 200
# {
#  "results": {
#   "customfields": {
#    "1": {
#     "_status_code": 200,
#     "_status_message": "Success operation on custom field: ",
#     "id": 188570,
#     "active": true,
#     "required": true,
#     "applies_to": "timesheet",
#     "type": "managed-list",
#     "short_code": "vin",
#     "regex_filter": "",
#     "name": "Vehicle Number",
#     "last_modified": "2025-08-08T22:02:05+00:00",
#     "created": "2025-08-08T22:02:05+00:00",
#     "ui_preference": "drop_down",
#     "required_customfields": [
#
#     ],
#     "show_to_all": true
#    }
#   }
#  }
# }

# %%
import requests

tsheets_url = "https://rest.tsheets.com/api/v1/timesheets"

payload = {
    "timesheets": {
        "1": {
            "user_id": 934085,
            "jobcode_id": 6828763,
            "start": "2025-08-08T08:00:00-05:00",
            "end": "2025-08-08T17:00:00-05:00",
            "notes": "Imported from Timeero"
        }
    }
}

headers = {
    "Authorization": "Bearer S.7__66ff92b4db402caf5da98f19235e26e39232bbc0",
    "Content-Type": "application/json",
}

response = requests.post(tsheets_url, json=payload, headers=headers)
print(response.status_code, response.text)
# Out:
# 417 {
#  "error": {
#   "code": 417,
#   "message": "Expectation Failed: data field missing"
#  }
# }

# %%
import requests

url = "https://rest.tsheets.com/api/v1/timesheets"

querystring = {
  "start_date":"2025-01-15",
  "end_date":"2025-08-25",
  "on_the_clock":"both",
}

payload = ""
headers = {
   'Authorization': "Bearer S.7__66ff92b4db402caf5da98f19235e26e39232bbc0",
  }

response = requests.request("GET", url, data=payload, headers=headers, params=querystring)

print(response.text)
# Out:
# {
#  "results": {
#   "timesheets": {
#    "680700348": {
#     "id": 680700348,
#     "state": "CLOSED",
#     "user_id": 934085,
#     "jobcode_id": 42255476,
#     "start": "2025-02-12T19:25:00+00:00",
#     "end": "2025-02-12T19:25:00+00:00",
#     "duration": 0,
#     "date": "2025-02-12",
#     "tz": 0,
#     "tz_str": "Europe\/London",
#     "type": "regular",
#     "location": "iPhone App",
#     "on_the_clock": false,
#     "locked": 0,
#     "notes": "",
#     "customfields": {
#      "187574": "Equipment 1",
#      "187576": "T",
#      "158061": "25",
#      "165358": "",
#      "188570": ""
#     },
#     "last_modified": "2025-02-12T19:24:19+00:00",
#     "distance_tracking": {
#      "calculated_meters": "2",
#      "manual_meters": null,
#      "snap_to_roads": null
#     },
#     "attached_files": [
#
#     ],
#     "created_by_user_id": 934085
#    },
#    "684032966": {
#     "id": 684032966,
#     "state": "CLOSED",
#     "user_id": 934085,
# ...

# %%
import requests

url = "https://rest.tsheets.com/api/v1/timesheets"

payload = {
    "data": [
        {
            "name": "Vehicle Number",
            "required": True,
            "active": True,
            "applies_to": "timesheet",
            "type": "managed-list",
            "show_to_all": True,
            "short_code": "vin"
        }
    ]
}

headers = {
    'Authorization': 'Bearer <TOKEN>',
    'Content-Type': 'application/json',
    }

response = requests.request("POST", url, data=payload, headers=headers)

print(response.text)

# %%
import requests
import json

# ==== CONFIG ====
ACCESS_TOKEN = "S.7__66ff92b4db402caf5da98f19235e26e39232bbc0"  # Replace with your TSheets OAuth token
API_URL = "https://rest.tsheets.com/api/v1/timesheets"

# Example user and jobcode IDs from TSheets
USER_ID = 934085        # Replace with an actual TSheets user_id
JOBCODE_ID = 42255476    # Replace with an actual TSheets jobcode_id

# Time entry (ISO 8601 format with timezone offset)
start_time = "2025-08-08T08:00:00-05:00"
end_time   = "2025-08-08T17:00:00-05:00"

# Request payload
payload = {
    "timesheets": {
        "1": {
            "user_id": USER_ID,
            "jobcode_id": JOBCODE_ID,
            "start": start_time,
            "end": end_time,
            "notes": "API created timesheet"
        }
    }
}

# Headers
headers = {
    "Authorization": f"Bearer {ACCESS_TOKEN}",
    "Content-Type": "application/json"
}

# Send POST request
response = requests.post(API_URL, headers=headers, json=payload)

# Output
print(f"Status Code: {response.status_code}")
print(json.dumps(response.json(), indent=2))
# Out:
# Status Code: 417
# {
#   "error": {
#     "code": 417,
#     "message": "Expectation Failed: data field missing"
#   }
# }

# %%
import requests

# Base URL for Timeero Public API
url = "https://api.timeero.app/api/public/timesheets"

# Headers with your API key
headers = {
    "Authorization": "Bearer R5F5FL1Zy1Qw1r9cvjCqaINBFOGXIoR91SqABtwAsScUGCnE8nmS3Y0Ws0ja0ruq"
}

# Optional: Filter by date range to limit results
params = {
    "date_range": "2025-06-01,2025-08-05",  # Adjust to your test range
    "page_size": 5
}

response = requests.get(url, headers=headers, params=params)

# Show the JSON response
print(response.json())
# Out:
# {'error_code': 401, 'error_message': 'Invalid api key.'}

# %%
# --- API Tokens ---
TSHEETS_ACCESS_TOKEN = "S.7__66ff92b4db402caf5da98f19235e26e39232bbc0"
# You need to get your Timeero API token.
TIMEERO_ACCESS_TOKEN = "Essh2i3vyVOLjouKLyoPsqKoZlRy7jd8uIunRlfuzFnPoCB1N4HSH7Yfb2uVsOK7"

# --- API Endpoints ---
TSHEETS_BASE_URL = "https://rest.tsheets.com/api/v1"
TIMEERO_BASE_URL = "https://api.timeero.app/api/public/timesheets"

# --- Mapping Dictionaries ---
# Maps Timeero user IDs to TSheets user IDs
user_mapping = {
    "TIMEERO_USER_ID_1": "106381",

    # Add all your employee mappings here
}

# Maps Timeero job IDs to TSheets job IDs
job_mapping = {
    "TIMEERO_JOB_ID_1": "456014", # Example from your data

}

# %%
import requests
import json

# Your existing setup
TSHEETS_ACCESS_TOKEN = "S.7__66ff92b4db402caf5da98f19235e26e39232bbc0"
TIMEERO_ACCESS_TOKEN = "Essh2i3vyVOLjouKLyoPsqKoZlRy7jd8uIunRlfuzFnPoCB1N4HSH7Yfb2uVsOK7"
TSHEETS_BASE_URL = "https://rest.tsheets.com/api/v1"
timeero_timesheet_url = "https://api.timeero.app/api/public/timesheets"

# Corrected headers (from previous fix)
timeero_headers = {
    "Authorization": TIMEERO_ACCESS_TOKEN,
    "Accept": "application/json"
}

# Corrected parameters
# The value for 'approved' is now a string "true"
params = {
    "date_range": "2025-07-06,2025-08-07",
    "page_size": 5,
    "approved": "true" # Change this from True to "true"
}

try:
    print(f"Fetching timesheets from Timeero URL: {timeero_timesheet_url}")
    response = requests.get(timeero_timesheet_url, headers=timeero_headers, params=params)
    response.raise_for_status()

    timeero_timesheet_data = response.json()
    print("Successfully fetched timesheets from Timeero.")
    print(json.dumps(timeero_timesheet_data, indent=4))
except requests.exceptions.HTTPError as e:
    print(f"HTTP error occurred: {e}")
    print(f"Response content: {response.text}")
    timeero_timesheet_data = None
except requests.exceptions.RequestException as e:
    print(f"An unexpected request error occurred: {e}")
    timeero_timesheet_data = None
# Out:
# Fetching timesheets from Timeero URL: https://api.timeero.app/api/public/timesheets
# Successfully fetched timesheets from Timeero.
# {
#     "meta_data": {
#         "pagination": {
#             "current_page": 1,
#             "first_page_url": "https://api.timeero.app/api/public/timesheets?page=1",
#             "from": 1,
#             "last_page": 1,
#             "last_page_url": "https://api.timeero.app/api/public/timesheets?page=1",
#             "next_page_url": null,
#             "path": "https://api.timeero.app/api/public/timesheets",
#             "per_page": 5,
#             "prev_page_url": null,
#             "to": 1,
#             "total": 1,
#             "options": true
#         }
#     },
#     "items": [
#         {
#             "id": 12830888,
#             "user_id": 106381,
#             "first_name": "Sri Pavan",
#             "last_name": "Pachipulusu",
#             "company_employee_id": null,
#             "notes": null,
# ...

# %%
import requests
import json
from datetime import datetime, timedelta

# --- API Tokens ---
TSHEETS_ACCESS_TOKEN = "S.7__66ff92b4db402caf5da98f19235e26e39232bbc0"
# Timeero access token is not needed in this script since you have the data
# TIMEERO_ACCESS_TOKEN = "Essh2i3vyVOLjouKLyoPsqKoZlRy7jd8uIunRlfuzFnPoCB1N4HSH7Yfb2uVsOK7"

# --- API Endpoints ---
TSHEETS_BASE_URL = "https://rest.tsheets.com/api/v1"

# --- Mapping Dictionaries ---
# Maps Timeero user IDs to TSheets user IDs
user_mapping = {
    106381: "934085" # Use integers for Timeero IDs since they are numbers in the response
}

# Maps Timeero job IDs to TSheets job IDs
job_mapping = {
    456014: "42255476" # Use integers for Timeero IDs
}

# The JSON data you successfully fetched from Timeero
timeero_data = {
    "meta_data": {
        "pagination": {
            "current_page": 1,
            "first_page_url": "https://api.timeero.app/api/public/timesheets?page=1",
            "from": 1,
            "last_page": 1,
            "last_page_url": "https://api.timeero.app/api/public/timesheets?page=1",
            "next_page_url": None,
            "path": "https://api.timeero.app/api/public/timesheets",
            "per_page": 5,
            "prev_page_url": None,
            "to": 1,
            "total": 1,
            "options": True
        }
    },
    "items": [
        {
            "id": 12830888,
            "user_id": 106381,
            "first_name": "Sri Pavan",
            "last_name": "Pachipulusu",
            "company_employee_id": None,
            "notes": None,
            "job_id": 456014,
            "job_name": "Sample Job",
            "task_id": 0,
            "task_name": None,
            "clock_in_time": "2025-07-17T06:32:52",
            "clock_in_address": None,
            "clock_in_latitude": 33.276419417079,
            "clock_in_longitude": -111.74004572511,
            "clock_out_time": "2025-07-17T06:38:48",
            "clock_out_address": None,
            "clock_out_latitude": 33.276466732988,
            "clock_out_longitude": -111.74014636915,
            "break_in_seconds": 0,
            "breaks": [],
            "duration": "0:05",
            "mileage": 0,
            "attachments": 1,
            "flagged": False,
            "approved": True,
            "approved_by": "Sri Pavan Pachipulusu",
            "custom_fields": None,
            "clock_in_timezone": "America/Phoenix",
            "clock_out_timezone": "America/Phoenix",
            "created_at": "2025-07-17T13:32:52",
            "updated_at": "2025-07-17T14:05:49"
        }
    ]
}

def create_tsheets_timesheet(timesheet_payload):
    """Sends a POST request to QuickBooks Time to create a new timesheet."""
    url = f"{TSHEETS_BASE_URL}/timesheets"
    headers = {
        "Authorization": f"Bearer {TSHEETS_ACCESS_TOKEN}",
        "Content-Type": "application/json",
        "Accept": "application/json"
    }

    try:
        response = requests.post(url, data=json.dumps(timesheet_payload), headers=headers)
        response.raise_for_status()
        print("Successfully created timesheet in QuickBooks Time.")
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"Error creating timesheet in QuickBooks Time: {e}")
        print(f"Response content: {response.text}")
        return None

def sync_single_timesheet(timeero_timesheet_data):
    """
    Takes a single timesheet data from Timeero, maps the IDs, and creates
    a new timesheet in QuickBooks Time.
    """
    if not timeero_timesheet_data or not timeero_timesheet_data.get('items'):
        print("No timesheet data to process.")
        return

    # Get the single timesheet record from the list
    timeero_ts = timeero_timesheet_data['items'][0]

    # Map user and job IDs. Note that the Timeero IDs are integers.
    try:
        tsheets_user_id = user_mapping[timeero_ts['user_id']]
        tsheets_job_id = job_mapping[timeero_ts['job_id']]
    except KeyError as e:
        print(f"Mapping not found for ID: {e}. Cannot sync timesheet.")
        return

    # Construct the QuickBooks Time payload
    tsheets_payload = {
        "timesheets": [
            {
                "user_id": tsheets_user_id,
                "jobcode_id": tsheets_job_id,
                # Use the 'start' and 'end' from the Timeero record.
                # Note: Timeero uses `clock_in_time` and `clock_out_time`
                # TSheets uses `start` and `end`.
                "start": timeero_ts['clock_in_time'],
                "end": timeero_ts['clock_out_time'],
                "notes": f"Synced from Timeero. Original ID: {timeero_ts['id']}"
            }
        ]
    }

    # Send the request to create the timesheet
    create_tsheets_timesheet(tsheets_payload)

# --- Execute the sync job ---
if __name__ == "__main__":
    sync_single_timesheet(timeero_data)
# Out:
# Error creating timesheet in QuickBooks Time: 417 Client Error: Expectation Failed for url: https://rest.tsheets.com/api/v1/timesheets
# Response content: {
#  "error": {
#   "code": 417,
#   "message": "Expectation Failed: data field missing"
#  }
# }

# %%
import requests
import json

# Your existing setup
TSHEETS_ACCESS_TOKEN = "S.7__914317b2fe3cd1d7ae1f37069948ffed10ee37db" # Use your new token here
TSHEETS_BASE_URL = "https://rest.tsheets.com/api/v1"

# The TSheets endpoint for fetching timesheets
tsheets_timesheet_url = f"{TSHEETS_BASE_URL}/timesheets"

# Correct headers for TSheets API
tsheets_headers = {
    "Authorization": f"Bearer {TSHEETS_ACCESS_TOKEN}",
    "Accept": "application/json"
}

# Add required query parameters to filter the results
# The API requires a date filter (start_date) and at least one other filter
params = {
    "start_date": "2025-08-01",
    "end_date": "2025-08-11",
    "user_ids": "934085"
}

try:
    print(f"Fetching timesheets from TSheets URL: {tsheets_timesheet_url}")
    # The 'params' argument adds the filter to the request URL
    response = requests.get(tsheets_timesheet_url, headers=tsheets_headers, params=params)
    response.raise_for_status()

    tsheets_data = response.json()
    print("Successfully fetched timesheets from TSheets.")
    print(json.dumps(tsheets_data, indent=4))
except requests.exceptions.HTTPError as e:
    print(f"HTTP error occurred: {e}")
    print(f"Response content: {response.text}")
except requests.exceptions.RequestException as e:
    print(f"An unexpected request error occurred: {e}")
# Out:
# Fetching timesheets from TSheets URL: https://rest.tsheets.com/api/v1/timesheets
# Successfully fetched timesheets from TSheets.
# {
#     "results": {
#         "timesheets": {
#             "723464716": {
#                 "id": 723464716,
#                 "state": "CLOSED",
#                 "user_id": 934085,
#                 "jobcode_id": 42255476,
#                 "start": "2025-08-07T10:37:26-07:00",
#                 "end": "2025-08-07T10:37:36-07:00",
#                 "duration": 10,
#                 "date": "2025-08-07",
#                 "tz": -7,
#                 "tz_str": "America/Phoenix",
#                 "type": "regular",
#                 "location": "iPhone App",
#                 "on_the_clock": false,
#                 "locked": 0,
#                 "notes": "",
#                 "customfields": {
#                     "158061": "",
#                     "165358": "",
#                     "187574": "Equipment 2",
#                     "187576": "Test"
# ...

# %%
import requests
import json
from datetime import datetime, timedelta

# --- API Tokens ---
# Use your new TSheets token
TSHEETS_ACCESS_TOKEN = "S.7__914317b2fe3cd1d7ae1f37069948ffed10ee37db"
TIMEERO_ACCESS_TOKEN = "Essh2i3vyVOLjouKLyoPsqKoZlRy7jd8uIunRlfuzFnPoCB1N4HSH7Yfb2uVsOK7"

# --- API Endpoints ---
TSHEETS_BASE_URL = "https://rest.tsheets.com/api/v1"
TIMEERO_TIMESHEET_URL = "https://api.timeero.app/api/public/timesheets"

# --- Mapping Dictionaries ---
# Maps Timeero user IDs (int) to TSheets user IDs (str)
user_mapping = {106381: "934085"}

# Maps Timeero job IDs (int) to TSheets job IDs (str)
job_mapping = {456014: "42255476"}

def fetch_timeero_timesheet():
    """Fetches a single timesheet record from Timeero."""
    params = {
        "date_range": "2025-07-06,2025-08-07",
        "page_size": 1,
        "approved": "true"
    }

    headers = {
        "Authorization": TIMEERO_ACCESS_TOKEN,
        "Accept": "application/json"
    }

    try:
        response = requests.get(TIMEERO_TIMESHEET_URL, headers=headers, params=params)
        response.raise_for_status()
        timeero_data = response.json()
        print("Successfully fetched timesheet from Timeero.")

        if timeero_data and timeero_data.get('items'):
            return timeero_data['items'][0]
        else:
            print("No timesheet data found in Timeero response.")
            return None
    except requests.exceptions.RequestException as e:
        print(f"Error fetching timesheet from Timeero: {e}")
        return None

def create_tsheets_timesheet(timeero_ts):
    """
    Creates a new timesheet in TSheets using a mapped record from Timeero.
    """
    if not timeero_ts:
        print("No timesheet record to sync.")
        return

    try:
        tsheets_user_id = user_mapping[timeero_ts['user_id']]
        tsheets_job_id = job_mapping[timeero_ts['job_id']]
    except KeyError as e:
        print(f"Mapping not found for ID: {e}. Cannot sync timesheet.")
        return

    tsheets_payload = {
        "timesheets": [
            {
                "user_id": tsheets_user_id,
                "jobcode_id": tsheets_job_id,
                "start": timeero_ts['clock_in_time'],
                "end": timeero_ts['clock_out_time'],
                "notes": f"Synced from Timeero. Original ID: {timeero_ts['id']}",
                "customfields": {
                    "187576": "30 minutes"
                }
            }
        ]
    }

    tsheets_headers = {
        "Authorization": f"Bearer {TSHEETS_ACCESS_TOKEN}",
        "Content-Type": "application/json",
        "Accept": "application/json"
    }

    try:
        print("\nAttempting to create timesheet in QuickBooks Time...")
        response = requests.post(f"{TSHEETS_BASE_URL}/timesheets", json=tsheets_payload, headers=tsheets_headers)
        response.raise_for_status()
        print("Successfully created timesheet in QuickBooks Time!")
        print(json.dumps(response.json(), indent=4))
    except requests.exceptions.RequestException as e:
        print(f"Error creating timesheet in QuickBooks Time: {e}")
        print(f"Response content: {response.text}")

if __name__ == "__main__":
    timeero_timesheet = fetch_timeero_timesheet()
    create_tsheets_timesheet(timeero_timesheet)
# Out:
# Successfully fetched timesheet from Timeero.
#
# Attempting to create timesheet in QuickBooks Time...
# Error creating timesheet in QuickBooks Time: 417 Client Error: Expectation Failed for url: https://rest.tsheets.com/api/v1/timesheets
# Response content: {
#  "error": {
#   "code": 417,
#   "message": "Expectation Failed: data field missing"
#  }
# }

# %%
import requests
import json
from datetime import datetime, timedelta

# --- API Tokens ---
TSHEETS_ACCESS_TOKEN = "S.7__914317b2fe3cd1d7ae1f37069948ffed10ee37db"
TIMEERO_ACCESS_TOKEN = "Essh2i3vyVOLjouKLyoPsqKoZlRy7jd8uIunRlfuzFnPoCB1N4HSH7Yfb2uVsOK7"

# --- API Endpoints ---
TSHEETS_BASE_URL = "https://rest.tsheets.com/api/v1"
TIMEERO_TIMESHEET_URL = "https://api.timeero.app/api/public/timesheets"

# --- Mapping Dictionaries ---
user_mapping = {106381: "934085"}
job_mapping = {456014: "42255476"}

def fetch_timeero_timesheet():
    """Fetches a single timesheet record from Timeero."""
    params = {
        "date_range": "2025-07-06,2025-08-07",
        "page_size": 1,
        "approved": "true"
    }

    headers = {
        "Authorization": TIMEERO_ACCESS_TOKEN,
        "Accept": "application/json"
    }

    try:
        response = requests.get(TIMEERO_TIMESHEET_URL, headers=headers, params=params)
        response.raise_for_status()
        timeero_data = response.json()
        print("Successfully fetched timesheet from Timeero.")

        if timeero_data and timeero_data.get('items'):
            return timeero_data['items'][0]
        else:
            print("No timesheet data found in Timeero response.")
            return None
    except requests.exceptions.RequestException as e:
        print(f"Error fetching timesheet from Timeero: {e}")
        return None

def create_tsheets_timesheet(timeero_ts):
    """
    Creates a new timesheet in TSheets using a mapped record from Timeero.
    """
    if not timeero_ts:
        print("No timesheet record to sync.")
        return

    try:
        tsheets_user_id = user_mapping[timeero_ts['user_id']]
        tsheets_job_id = job_mapping[timeero_ts['job_id']]
    except KeyError as e:
        print(f"Mapping not found for ID: {e}. Cannot sync timesheet.")
        return

    # Use the payload structure that worked for you in Postman
    tsheets_payload = {
        "data": [
            {
                "user_id": tsheets_user_id,
                "type": "regular",
                "jobcode_id": tsheets_job_id,
                "start": timeero_ts['clock_in_time'],
                "end": timeero_ts['clock_out_time'],
                "notes": f"Synced from Timeero. Original ID: {timeero_ts['id']}"
            }
        ]
    }

    tsheets_headers = {
        "Authorization": f"Bearer {TSHEETS_ACCESS_TOKEN}",
        "Content-Type": "application/json",
        "Accept": "application/json"
    }

    try:
        print("\nAttempting to create timesheet in QuickBooks Time...")
        response = requests.post(f"{TSHEETS_BASE_URL}/timesheets", json=tsheets_payload, headers=tsheets_headers)
        response.raise_for_status()
        print("Successfully created timesheet in QuickBooks Time!")
        print(json.dumps(response.json(), indent=4))
    except requests.exceptions.RequestException as e:
        print(f"Error creating timesheet in QuickBooks Time: {e}")
        print(f"Response content: {response.text}")

if __name__ == "__main__":
    timeero_timesheet = fetch_timeero_timesheet()
    create_tsheets_timesheet(timeero_timesheet)
# Out:
# Successfully fetched timesheet from Timeero.
#
# Attempting to create timesheet in QuickBooks Time...
# Successfully created timesheet in QuickBooks Time!
# {
#     "results": {
#         "timesheets": {
#             "1": {
#                 "_status_code": 417,
#                 "_status_message": "Expectation Failed",
#                 "_status_extra": "'local_start' timestamp [2025-07-17T06:32:52] is not in valid ISO-8601 format"
#             }
#         }
#     }
# }

# %%
pip install python-dateutil

# %%
import requests
import json
from datetime import datetime
from dateutil import tz

# --- API Tokens ---
TSHEETS_ACCESS_TOKEN = "S.7__9d62d475481d3adb9da8bf90a056c3c7385084be"
TIMEERO_ACCESS_TOKEN = "zfiOrV5vnzESVwkk2ddz63lQn0IgrZLjC4iDv17EXOuuaEGsdoarkPuqDSfVj3kz"

# --- API Endpoints ---
TSHEETS_BASE_URL = "https://rest.tsheets.com/api/v1"
TIMEERO_TIMESHEET_URL = "https://api.timeero.app/api/public/timesheets"

# --- Mapping Dictionaries ---
user_mapping = {106381: "934085"}
job_mapping = {456014: "42255476"}

def fetch_timeero_timesheet():
    """Fetches a single timesheet record from Timeero."""
    params = {
        "date_range": "2025-08-01,2025-08-07",
        "page_size": 1,
        "approved": "true"
    }

    headers = {
        "Authorization": TIMEERO_ACCESS_TOKEN,
        "Accept": "application/json"
    }

    try:
        response = requests.get(TIMEERO_TIMESHEET_URL, headers=headers, params=params)
        response.raise_for_status()
        timeero_data = response.json()
        print("Successfully fetched timesheet from Timeero.")

        if timeero_data and timeero_data.get('items'):
            return timeero_data['items'][0]
        else:
            print("No timesheet data found in Timeero response.")
            return None
    except requests.exceptions.RequestException as e:
        print(f"Error fetching timesheet from Timeero: {e}")
        return None

def create_tsheets_timesheet(timeero_ts):
    """
    Creates a new timesheet in TSheets using a mapped record from Timeero.
    """
    if not timeero_ts:
        print("No timesheet record to sync.")
        return

    try:
        tsheets_user_id = user_mapping[timeero_ts['user_id']]
        tsheets_job_id = job_mapping[timeero_ts['job_id']]
    except KeyError as e:
        print(f"Mapping not found for ID: {e}. Cannot sync timesheet.")
        return

    # --- Timezone Conversion ---
    # The Timeero timestamps are naive (no timezone info).
    # We need to add the timezone offset to them.
    from_zone = tz.gettz(timeero_ts['clock_in_timezone'])
    to_zone = tz.gettz(timeero_ts['clock_out_timezone'])

    start_naive = datetime.fromisoformat(timeero_ts['clock_in_time'])
    end_naive = datetime.fromisoformat(timeero_ts['clock_out_time'])

    start_aware = start_naive.replace(tzinfo=from_zone)
    end_aware = end_naive.replace(tzinfo=to_zone)

    # Format the aware datetime objects back into the required ISO 8601 string
    tsheets_start_time = start_aware.isoformat()
    tsheets_end_time = end_aware.isoformat()

    # Use the payload structure that worked for you in Postman
    tsheets_payload = {
        "data": [
            {
                "user_id": tsheets_user_id,
                "type": "regular",
                "jobcode_id": tsheets_job_id,
                # Use the newly formatted timestamps
                "start": tsheets_start_time,
                "end": tsheets_end_time,
                "notes": f"Synced from Timeero. Original ID: {timeero_ts['id']}"
            }
        ]
    }

    tsheets_headers = {
        "Authorization": f"Bearer {TSHEETS_ACCESS_TOKEN}",
        "Content-Type": "application/json",
        "Accept": "application/json"
    }

    try:
        print("\nAttempting to create timesheet in QuickBooks Time...")
        response = requests.post(f"{TSHEETS_BASE_URL}/timesheets", json=tsheets_payload, headers=tsheets_headers)
        response.raise_for_status()
        print("Successfully created timesheet in QuickBooks Time!")
        print(json.dumps(response.json(), indent=4))
    except requests.exceptions.RequestException as e:
        print(f"Error creating timesheet in QuickBooks Time: {e}")
        print(f"Response content: {response.text}")

if __name__ == "__main__":
    timeero_timesheet = fetch_timeero_timesheet()
    create_tsheets_timesheet(timeero_timesheet)
# Out:
# Successfully fetched timesheet from Timeero.
# No timesheet data found in Timeero response.
# No timesheet record to sync.

# %%
pip install requests python-dateutil

# %%
# !python /sync_script.py
# Out:
# Error: mapping.json file not found.

# %%
# !pip install requests python-dateutil

# %%
# !python3 sync_script.py
# Out:
# python3: can't open file '/content/sync_script.py': [Errno 2] No such file or directory

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# /content
# ['.config', '__pycache__', 'sample_data']

# %%
import os
os.chdir('/run/user/Timeero')

# %%
# !python3 sync_script.py
# Out:
# Enter the start date (YYYY-MM-DD): 2025-07-30
# Enter the end date (YYYY-MM-DD): 2025-08-05
#
# Starting daily sync for date: 2025-07-30...
# Successfully fetched timesheets from Timeero for 2025-07-30.
#
# Attempting to create timesheet for Timeero ID: 12830888...
# Failed to create timesheet. TSheets API returned an error.
# Full response: {
#   "results": {
#     "timesheets": {
#       "1": {
#         "_status_code": 406,
#         "_status_message": "Not Acceptable",
#         "_status_extra": "Timesheets overlap! \n\nbakwarte2@gmail.com was on the clock\nat the clock-out time you specified.\nTry an earlier clock-out time"
#       }
#     }
#   }
# }
#
# Starting daily sync for date: 2025-07-31...
# Successfully fetched timesheets from Timeero for 2025-07-31.
#
# Attempting to create timesheet for Timeero ID: 12830888...
# Failed to create timesheet. TSheets API returned an error.
# Full response: {
#   "results": {
#     "timesheets": {
#       "1": {
# ...

# %%
import requests
import json
from datetime import datetime
from dateutil import tz

# --- API Tokens ---
TSHEETS_ACCESS_TOKEN = "S.7__9d62d475481d3adb9da8bf90a056c3c7385084be"
TIMEERO_ACCESS_TOKEN = "zfiOrV5vnzESVwkk2ddz63lQn0IgrZLjC4iDv17EXOuuaEGsdoarkPuqDSfVj3kz"

# --- API Endpoints ---
TSHEETS_BASE_URL = "https://rest.tsheets.com/api/v1"
TIMEERO_TIMESHEET_URL = "https://api.timeero.app/api/public/timesheets"

# --- Mapping Dictionaries ---
user_mapping = {106381: "934085"}
job_mapping = {456014: "42255476"}

def fetch_timeero_timesheet():
    """Fetches a single timesheet record from Timeero."""
    params = {
        "date_range": "2025-07-16,2025-07-22",
        "page_size": 1,
        "approved": "true"
    }

    headers = {
        "Authorization": TIMEERO_ACCESS_TOKEN,
        "Accept": "application/json"
    }

    try:
        response = requests.get(TIMEERO_TIMESHEET_URL, headers=headers, params=params)
        response.raise_for_status()
        timeero_data = response.json()
        print("Successfully fetched timesheet from Timeero.")

        if timeero_data and timeero_data.get('items'):
            return timeero_data['items'][0]
        else:
            print("No timesheet data found in Timeero response.")
            return None
    except requests.exceptions.RequestException as e:
        print(f"Error fetching timesheet from Timeero: {e}")
        return None

def create_tsheets_timesheet(timeero_ts):
    """
    Creates a new timesheet in TSheets using a mapped record from Timeero.
    """
    if not timeero_ts:
        print("No timesheet record to sync.")
        return

    try:
        tsheets_user_id = user_mapping[timeero_ts['user_id']]
        tsheets_job_id = job_mapping[timeero_ts['job_id']]
    except KeyError as e:
        print(f"Mapping not found for ID: {e}. Cannot sync timesheet.")
        return

    # --- Timezone Conversion ---
    # The Timeero timestamps are naive (no timezone info).
    # We need to add the timezone offset to them.
    from_zone = tz.gettz(timeero_ts['clock_in_timezone'])
    to_zone = tz.gettz(timeero_ts['clock_out_timezone'])

    start_naive = datetime.fromisoformat(timeero_ts['clock_in_time'])
    end_naive = datetime.fromisoformat(timeero_ts['clock_out_time'])

    start_aware = start_naive.replace(tzinfo=from_zone)
    end_aware = end_naive.replace(tzinfo=to_zone)

    # Format the aware datetime objects back into the required ISO 8601 string
    tsheets_start_time = start_aware.isoformat()
    tsheets_end_time = end_aware.isoformat()

    # Use the payload structure that worked for you in Postman
    tsheets_payload = {
        "data": [
            {
                "user_id": tsheets_user_id,
                "type": "regular",
                "jobcode_id": tsheets_job_id,
                # Use the newly formatted timestamps
                "start": tsheets_start_time,
                "end": tsheets_end_time,
                "notes": f"Synced from Timeero. Original ID: {timeero_ts['id']}"
            }
        ]
    }

    tsheets_headers = {
        "Authorization": f"Bearer {TSHEETS_ACCESS_TOKEN}",
        "Content-Type": "application/json",
        "Accept": "application/json"
    }

    try:
        print("\nAttempting to create timesheet in QuickBooks Time...")
        response = requests.post(f"{TSHEETS_BASE_URL}/timesheets", json=tsheets_payload, headers=tsheets_headers)
        response.raise_for_status()
        print("Successfully created timesheet in QuickBooks Time!")
        print(json.dumps(response.json(), indent=4))
    except requests.exceptions.RequestException as e:
        print(f"Error creating timesheet in QuickBooks Time: {e}")
        print(f"Response content: {response.text}")

if __name__ == "__main__":
    timeero_timesheet = fetch_timeero_timesheet()
    create_tsheets_timesheet(timeero_timesheet)
# Out:
# Successfully fetched timesheet from Timeero.
#
# Attempting to create timesheet in QuickBooks Time...
# Successfully created timesheet in QuickBooks Time!
# {
#     "results": {
#         "timesheets": {
#             "1": {
#                 "_status_code": 200,
#                 "_status_message": "Created",
#                 "id": 725166496,
#                 "state": "CLOSED",
#                 "user_id": 934085,
#                 "jobcode_id": 42255476,
#                 "start": "2025-07-17T06:32:52-07:00",
#                 "end": "2025-07-17T06:38:48-07:00",
#                 "duration": 356,
#                 "date": "2025-07-17",
#                 "tz": -7,
#                 "tz_str": "",
#                 "type": "regular",
#                 "location": "New Test",
#                 "on_the_clock": false,
#                 "locked": 0,
#                 "notes": "Synced from Timeero. Original ID: 12830888",
#                 "customfields": {
# ...
